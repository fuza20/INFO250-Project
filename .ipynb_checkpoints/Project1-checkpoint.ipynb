# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("datasets/project1_dataset.csv")
labels =  ["no_datapoints","no_features", "datatype","algorithm","preprocessing_energy(J)"]
dataset[labels]
# Out:
#      no_datapoints  no_features datatype       algorithm  \
# 0             3900         6535    int32  Multinomial NB
# 1             3900          816    int32   Decision Tree
# 2             3900         1633    int32   Decision Tree
# 3             3900         8169    int64        AdaBoost
# 4             3900         8169    int32             SVM
# ..             ...          ...      ...             ...
# 765           3900         8169    int32   Decision Tree
# 766           2730         8169    int32        AdaBoost
# 767           3900          816    int32   Random Forest
# 768           2340         8169    int32             SVM
# 769           2340         8169    int32   Decision Tree
#
#      preprocessing_energy(J)
# 0                   0.137261
# 1                   0.132106
# 2                   0.186762
# 3                   0.008649
# 4                   0.014479
# ..                       ...
# 765                 0.025277
# 766                 0.017277
# ...
